# %%
test_q = '/home/zhangkechi/workspace/riddle/dataset/test.txt'
with open(test_q,'r') as f:
    test_q_data = f.readlines()
test_q_data = [x.strip() for x in test_q_data]

# %%
import pandas as pd

# %%
train_pd = pd.read_csv('/home/zhangkechi/workspace/riddle/dataset/train.csv')
train_q_data = list(train_pd['Q'])

# %%
valid_pd = pd.read_csv('/home/zhangkechi/workspace/riddle/dataset/valid.csv')
valid_q_data = list(valid_pd['Q'])

# %%
train_valid_q_data = train_q_data + valid_q_data

# %%
in_data = []
for e in test_q_data:
    if e in train_valid_q_data:
        in_data.append(e)

# %%
len(in_data)
# Out:
# 221

# %%
in_data
# Out:
# ['点滴积累方有为',
#  '一手遮不住太阳',
#  '星月交映日落时',
#  '开仓济粮',
#  '西汉灭亡东汉兴',
#  '一旦不能有，输来其间',
#  '不要开口闭口总是钱',
#  '爱上姣娥',
#  '我在新乡',
#  '白练如珠倚云生',
#  '石头记故事',
#  '人归落雁后',
#  '千里相逢',
#  '烟消日出人不见',
#  '个个同心助他人',
#  '星星出来太阳落下',
#  '一日之计在于晨',
#  '个个参与共扫黄',
#  '金牛凿破人间路',
#  '改革旧貌得第一',
#  '枝头莺鸟飞',
#  '林木参差透曙光',
#  '云间新月影如钩',
#  '陶后鲜有闻',
#  '手无寸铁',
#  '非同小可',
#  '敝帽半遮花半掩',
#  '鸵鸟奔跑入镜头',
#  '客人一到置水酒',
#  '胡乱编造无人信',
#  '四面围墙门不闭',
#  '千里共婵娟',
#  '浅滩停步听麝声',
#  '门可罗雀',
#  '是非只为多开口',
#  '古钱',
#  '从我做起',
#  '点滴积累可成金',
#  '推心置腹',
#  '儿童节',
#  '自小离乱到异乡',
#  '北京日当头',
#  '敝帽半遮花半露',
#  '夜夜减清辉',
#  '六桥夕照映秋波',
#  '马上行动',
#  '二十四小时',
#  '先机已失错开言',
#  '连日有雨',
#  '层峦叠翠',
#  '猴子捞月',
#  '兼顾千金',
#  '话锋相对',
#  '赞扬',
#  '眼前一片月',
#  '几处早争暖树',
#  '点滴积累放手拼',
#  '招贤入室',
#  '天上有个太阳',
#  '二度梅',
#  '落花盈我衣',
#  '步履维艰',
#  '人行横道',
#  '膻',
#  '孔雀东南飞',
#  '脱下上衣缝两针',
#  '长流夜郎得赦还',
#  '米芾行楷带草书',
#  '夜幕降临到贵州',
#  '百亩秧苗换新容',
#  '一念之差',
#  '说话有力',
#  '莫把金针度与人',
#  '此中人语云',
#  '早上一别卓飞君',
#  '国庆的早晨',
#  '四方归心，统一和平',
#  '二十载成就有目共睹',
# ...
